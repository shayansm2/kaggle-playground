# %%
import pandas as pd
import numpy as np
from datasets import Dataset
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification, DataCollatorWithPadding

# %%
questions = pd.read_csv('data/test_questions.csv')
answers = pd.read_csv('data/test_answers.csv')

# %%
number_of_qa = len(questions)

# Create a range from 1 to 100
range_ids = np.arange(number_of_qa)

# Create a meshgrid
col1, col2 = np.meshgrid(range_ids, range_ids)

# Flatten the arrays and create a DataFrame
df = pd.DataFrame({'question_row_id': col1.flatten(), 'answer_row_id': col2.flatten()})

# Display the DataFrame
df
# Out:
#         question_row_id  answer_row_id
# 0                     0              0
# 1                     1              0
# 2                     2              0
# 3                     3              0
# 4                     4              0
# ...                 ...            ...
# 266251              511            515
# 266252              512            515
# 266253              513            515
# 266254              514            515
# 266255              515            515
#
# [266256 rows x 2 columns]

# %%
questions.head()
# Out:
#    question_id                                           question  \
# 0          707  How much of an effort would it be to use AWS i...
# 1       534450  Can you talk about linear regression and regul...
# 2       996163  Can you please explain the Python Black setup ...
# 3       860215  How many portfolio projects apart from the cou...
# 4       980124  Can you talk more about the final project? Wha...
#
#                       course  year                   candidate_answers
# 0  Data Engineering Zoomcamp  2023   336232,337669,258304,47681,767296
# 1  Machine Learning Zoomcamp  2022   231208,282072,86769,573165,138373
# 2  Data Engineering Zoomcamp  2023   571892,816559,47681,337669,336232
# 3  Machine Learning Zoomcamp  2022  643931,988549,918931,235894,608866
# 4  Data Engineering Zoomcamp  2023   384381,337669,258304,47681,747722

# %%
answers.head()
# Out:
#    answer_id                                             answer  \
# 0     767296  Alexey\nProbably more than you want to put in....
# 1     573165  Yes, I can. There is actually an entire module...
# 2     571892  Jeff\nI can try. I like Black a lot. If you ju...
# 3     988549  Again, you’ll probably hate me soon for saying...
# 4     384381  Alexey\nThe first thing about the dataset – wh...
#
#                       course  year attachments_files
# 0  Data Engineering Zoomcamp  2023               NaN
# 1  Machine Learning Zoomcamp  2022               NaN
# 2  Data Engineering Zoomcamp  2023               NaN
# 3  Machine Learning Zoomcamp  2022               NaN
# 4  Data Engineering Zoomcamp  2023               NaN

# %%
df['question_id'] = df['question_row_id'].map(questions['question_id'])
df['question'] = df['question_row_id'].map(questions['question'])
df['question_course'] = df['question_row_id'].map(questions['course'])
df['question_year'] = df['question_row_id'].map(questions['year'])

df['answer_id'] = df['answer_row_id'].map(answers['answer_id'])
df['answer'] = df['answer_row_id'].map(answers['answer'])
df['answer_course'] = df['answer_row_id'].map(answers['course'])
df['answer_year'] = df['answer_row_id'].map(answers['year'])

# %%
df = df[df['question_course'] == df['answer_course']]
df = df[df['question_year'] == df['answer_year']]
df.index = df.index.rename('idx')
df.drop(columns=['question_row_id', 'answer_row_id', 'question_id', 'answer_id', 'question_course', 'answer_course', 'question_year', 'answer_year'], inplace=True)

# %%
df
# Out:
#                                                  question  \
# idx
# 0       How much of an effort would it be to use AWS i...
# 2       Can you please explain the Python Black setup ...
# 4       Can you talk more about the final project? Wha...
# 8       I read a book that said the data engineering l...
# 9       If we consider professional certification for ...
# ...                                                   ...
# 266245                   How to get out of tutorial hell?
# 266246  Can you explain what exactly model.fit(x_train...
# 266247  What to do after courses? Where do you see us ...
# 266248  What would be the main skills/algorithms/tools...
# 266255  Can you explain regularization better? I did n...
#
#                                                    answer
# idx
# 0       Alexey\nProbably more than you want to put in....
# 2       Alexey\nProbably more than you want to put in....
# 4       Alexey\nProbably more than you want to put in....
# 8       Alexey\nProbably more than you want to put in....
# 9       Alexey\nProbably more than you want to put in....
# ...                                                   ...
# 266245  I need more information to actually help you h...
# 266246  I need more information to actually help you h...
# 266247  I need more information to actually help you h...
# 266248  I need more information to actually help you h...
# 266255  I need more information to actually help you h...
#
# [137178 rows x 2 columns]

# %%
raw_datasets = Dataset.from_pandas(df)
raw_datasets
# Out:
# Dataset({
#     features: ['question', 'answer', 'idx'],
#     num_rows: 137178
# })

# %%
checkpoint = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

def tokenize_function(record):
    return tokenizer(record["question"], record["answer"], truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
tokenized_datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Map:   0%|          | 0/137178 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'answer', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 137178
# })

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="tf")

# %%
dataset = tokenized_datasets.to_tf_dataset(
    columns=["attention_mask", "input_ids", "token_type_ids"],
    shuffle=True,
    collate_fn=data_collator,
    batch_size=100,
)

# %%
model = TFAutoModelForSequenceClassification.from_pretrained('model.h5')
# Out:
# Some layers from the model checkpoint at model.h5 were not used when initializing TFBertForSequenceClassification: ['dropout_37']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at model.h5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
preds = model.predict(dataset)
# Out:
#    2/1372 [..............................] - ETA: 11:16:24

# %%
from py_scripts.model_interface import predict_probabilities

# %%
df_test = df.head(100)
def get_pred(q, ans) -> int :
    return predict_probabilities(q, ans)[1]

df_test['prob'] = df_test.apply(lambda row: get_pred(row['question'], row['answer']), axis=1)
df_test
# Out:
# /var/folders/s6/6bpn1bsx1671knt15gtsc0pm0000gp/T/ipykernel_26225/3360408251.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['prob'] = df_test.apply(lambda row: get_pred(row['question'], row['answer']), axis=1)
#                                               question  \
# idx
# 0    How much of an effort would it be to use AWS i...
# 2    Can you please explain the Python Black setup ...
# 4    Can you talk more about the final project? Wha...
# 8    I read a book that said the data engineering l...
# 9    If we consider professional certification for ...
# ..                                                 ...
# 206  Data lakes are like folders. We save data befo...
# 209  What is the relationship between Prefect agent...
# 218  How many finishers do you expect at the end of...
# 223  Can you share with us some real-work data clea...
# 224               How can we contribute to the course?
#
#                                                 answer      prob
# idx
# 0    Alexey\nProbably more than you want to put in....  0.972288
# 2    Alexey\nProbably more than you want to put in....  0.067522
# 4    Alexey\nProbably more than you want to put in....  0.157995
# 8    Alexey\nProbably more than you want to put in....  0.189315
# 9    Alexey\nProbably more than you want to put in....  0.199016
# ..                                                 ...       ...
# 206  Alexey\nProbably more than you want to put in....  0.103819
# 209  Alexey\nProbably more than you want to put in....  0.075144
# 218  Alexey\nProbably more than you want to put in....  0.140364
# 223  Alexey\nProbably more than you want to put in....  0.086829
# 224  Alexey\nProbably more than you want to put in....  0.454602
#
# [100 rows x 3 columns]

# %% [markdown]
# 10 -> 2.6s
#
# 50 -> 13.2s
#
# 100 -> 27s
#
# 100,000 -> 27000s

# %%
len(df) * 27 / 100 / 3600
# Out:
# 10.28835

# %%
df
# Out:
#                                                  question  \
# idx
# 0       How much of an effort would it be to use AWS i...
# 2       Can you please explain the Python Black setup ...
# 4       Can you talk more about the final project? Wha...
# 8       I read a book that said the data engineering l...
# 9       If we consider professional certification for ...
# ...                                                   ...
# 266245                   How to get out of tutorial hell?
# 266246  Can you explain what exactly model.fit(x_train...
# 266247  What to do after courses? Where do you see us ...
# 266248  What would be the main skills/algorithms/tools...
# 266255  Can you explain regularization better? I did n...
#
#                                                    answer
# idx
# 0       Alexey\nProbably more than you want to put in....
# 2       Alexey\nProbably more than you want to put in....
# 4       Alexey\nProbably more than you want to put in....
# 8       Alexey\nProbably more than you want to put in....
# 9       Alexey\nProbably more than you want to put in....
# ...                                                   ...
# 266245  I need more information to actually help you h...
# 266246  I need more information to actually help you h...
# 266247  I need more information to actually help you h...
# 266248  I need more information to actually help you h...
# 266255  I need more information to actually help you h...
#
# [137178 rows x 2 columns]
